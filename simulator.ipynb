# %%
import csv
import os
import cv2
import matplotlib.pyplot as plt
from random import randint
import numpy as np
# %matplotlib inline

lines = []
with open('./data1/driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        lines.append(line)
        
images = []
measurements = []

for line in lines:
    source_path = line[0]
    pth, filename = os.path.split(source_path)
    current_path = './data1/IMG/' + filename
    image = cv2.imread(current_path)
    images.append(image)
    measurement = float(line[3])
    measurements.append(measurement)
    
       
# print some random images:

for i in range(3):
   # plt.imshow(images[randint(0,len(images))])
   # plt.show()
    print(images[0].shape)
    

# load data into array

X_train = np.array(images)
Y_train = np.array(measurements)

from keras.models import Sequential
from keras.layers import Flatten, Dense

model = Sequential()
model.add(Flatten(input_shape=(160,320,3)))
model.add(Dense(1))

model.compile(loss='mse', optimizer = 'adam')
model.fit(X_train,Y_train,validation_split=0.2, shuffle = True, nb_epoch=20)

model.save('model.h5_1')
# Out:
# (160, 320, 3)
# (160, 320, 3)
# (160, 320, 3)
# c:\users\ramesh_bv\appdata\local\programs\python\python36\lib\site-packages\keras\models.py:939: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 1272 samples, validate on 319 samples
# Epoch 1/20
# 1272/1272 [==============================] - 4s 3ms/step - loss: 44209569.8941 - val_loss: 2268497.0717
# Epoch 2/20
# 1272/1272 [==============================] - 3s 2ms/step - loss: 696600.6659 - val_loss: 22561.0389
# Epoch 3/20
# 1272/1272 [==============================] - 3s 2ms/step - loss: 22771.0780 - val_loss: 13611.1004
# Epoch 4/20
# 1272/1272 [==============================] - 3s 3ms/step - loss: 8082.7379 - val_loss: 9041.6767
# Epoch 5/20
# 1272/1272 [==============================] - 3s 2ms/step - loss: 6095.4570 - val_loss: 7324.2500
# Epoch 6/20
# ...

# %%
# model change: added lambda layer

import csv
import os
import cv2
import matplotlib.pyplot as plt
from random import randint
import numpy as np
# %matplotlib inline

lines = []
with open('./data1/driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        lines.append(line)
        
images = []
measurements = []

for line in lines:
    source_path = line[0]
    pth, filename = os.path.split(source_path)
    current_path = './data1/IMG/' + filename
    image = cv2.imread(current_path)
    images.append(image)
    measurement = float(line[3])
    measurements.append(measurement)
    
       
# print some random images:

for i in range(3):
   # plt.imshow(images[randint(0,len(images))])
   # plt.show()
    print(images[0].shape)
    

# load data into array

X_train = np.array(images)
Y_train = np.array(measurements)

from keras.models import Sequential
from keras.layers import Flatten, Dense
from keras.layers import Lambda


model = Sequential()
model.add(Lambda(lambda x: (x /255.0) - 0.5, input_shape=(160,320,3)))

model.add(Flatten(input_shape=(160,320,3)))
model.add(Dense(1))

model.compile(loss='mse', optimizer = 'adam')
model.fit(X_train,Y_train,validation_split=0.2, shuffle = True, nb_epoch=11)

model.save('model.h5_2')
# Out:
# (160, 320, 3)
# (160, 320, 3)
# (160, 320, 3)
# c:\users\ramesh_bv\appdata\local\programs\python\python36\lib\site-packages\keras\models.py:939: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 1272 samples, validate on 319 samples
# Epoch 1/11
# 1272/1272 [==============================] - 8s 6ms/step - loss: 11.0871 - val_loss: 3.2625
# Epoch 2/11
# 1272/1272 [==============================] - 6s 5ms/step - loss: 2.3193 - val_loss: 1.1469
# Epoch 3/11
# 1272/1272 [==============================] - 6s 5ms/step - loss: 1.0053 - val_loss: 1.3665
# Epoch 4/11
# 1272/1272 [==============================] - 6s 5ms/step - loss: 0.7252 - val_loss: 0.5008
# Epoch 5/11
# 1272/1272 [==============================] - 6s 5ms/step - loss: 0.5251 - val_loss: 0.3603
# Epoch 6/11
# 1272/1272 [==============================] - 6s 4ms/step - loss: 0.4697 - val_loss: 0.4636
# Epoch 7/11
# ...

# %%
# model change: added lambda layer AND CONvolution2d

import csv
import os
import cv2
import matplotlib.pyplot as plt
from random import randint
import numpy as np
# %matplotlib inline

lines = []
with open('./data/driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        lines.append(line)
        
images = []
measurements = []

for line in lines:
    source_path = line[0]
    pth, filename = os.path.split(source_path)
    current_path = './data/IMG/' + filename
    image = cv2.imread(current_path)
    images.append(image)
    measurement = float(line[3])
    measurements.append(measurement)
    
       
# print some random images:

for i in range(3):
   # plt.imshow(images[randint(0,len(images))])
   # plt.show()
    print(images[0].shape)
    

# load data into array

X_train = np.array(images)
Y_train = np.array(measurements)

from keras.models import Sequential
from keras.layers import Flatten, Dense
from keras.layers import Lambda
from keras.layers import Convolution2D
from keras.layers.pooling import MaxPooling2D


model = Sequential()
model.add(Lambda(lambda x: (x /255.0) - 0.5, input_shape=(160,320,3)))
model.add(Convolution2D(6,5,5, activation='relu'))
model.add(MaxPooling2D())
model.add(Convolution2D(6,5,5, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(120))
model.add(Dense(84))
model.add(Dense(1))

model.compile(loss='mse', optimizer = 'adam')
model.fit(X_train,Y_train,validation_split=0.2, shuffle = True, nb_epoch=11)

model.save('model.h5_3')
# Out:
# (160, 320, 3)
# (160, 320, 3)
# (160, 320, 3)
# C:\Users\ramesh_bv\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:52: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(6, (5, 5), activation="relu")`
# C:\Users\ramesh_bv\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:54: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(6, (5, 5), activation="relu")`
# c:\users\ramesh_bv\appdata\local\programs\python\python36\lib\site-packages\keras\models.py:939: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 6428 samples, validate on 1608 samples
# Epoch 1/11
# 6428/6428 [==============================] - 489s 76ms/step - loss: 0.0496 - val_loss: 0.0167
# Epoch 2/11
# 6428/6428 [==============================] - 484s 75ms/step - loss: 0.0132 - val_loss: 0.0131
# Epoch 3/11
# ...

# %%
# model change: added lambda layer AND CONvolution2d. added data augmentation
import csv
import os
import cv2
import matplotlib.pyplot as plt
from random import randint
import numpy as np
# %matplotlib inline

lines = []
with open('./data/driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        lines.append(line)
        
        
images = []
measurements = []

for line in lines:
    source_path = line[0]
    pth, filename = os.path.split(source_path)
    current_path = './data/IMG/' + filename
    image = cv2.imread(current_path)
    image_flipped = np.fliplr(image)
    images.append(image)
    measurement = float(line[3])
    measurements.append(measurement)
    images.append(image_flipped)
    measurements.append(-measurement)
    
    
       
# print some random images:

for i in range(3):
    randno = randint(0,len(images))
    plt.imshow(images[randno])
    plt.imshow(images_flipped[randno])
    
    plt.show()
    print(images[0].shape)
    

# load data into array

X_train = np.array(images)
Y_train = np.array(measurements)

from keras.models import Sequential
from keras.layers import Flatten, Dense
from keras.layers import Lambda
from keras.layers import Convolution2D
from keras.layers.pooling import MaxPooling2D


model = Sequential()
model.add(Lambda(lambda x: (x /255.0) - 0.5, input_shape=(160,320,3)))
model.add(Convolution2D(6,5,5, activation='relu'))
model.add(MaxPooling2D())
model.add(Convolution2D(6,5,5, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(120))
model.add(Dense(84))
model.add(Dense(1))

model.compile(loss='mse', optimizer = 'adam')
model.fit(X_train,Y_train,validation_split=0.2, shuffle = True, nb_epoch=11)

model.save('model.h5_4')

# %%
# model change: added lambda layer AND CONvolution2d. added data augmentation
import csv
import os
import cv2
import matplotlib.pyplot as plt
from random import randint
import numpy as np
# %matplotlib inline

lines = []
with open('./data/driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        lines.append(line)
        
        
images = []
measurements = []

for line in lines:
    source_path = line[0]
    pth, filename = os.path.split(source_path)
    current_path = './data/IMG/' + filename
    image = cv2.imread(current_path)
    image_flipped = np.fliplr(image)
    images.append(image)
    measurement = float(line[3])
    measurements.append(measurement)
    images.append(image_flipped)
    measurements.append(-measurement)
    
    
       
# print some random images:

for i in range(3):
    randno = randint(0,len(images))
    plt.imshow(images[randno])
    plt.imshow(images_flipped[randno])
    
    plt.show()
    print(images[0].shape)
    

# load data into array

X_train = np.array(images)
Y_train = np.array(measurements)

from keras.models import Sequential
from keras.layers import Flatten, Dense
from keras.layers import Lambda
from keras.layers import Convolution2D
from keras.layers.pooling import MaxPooling2D


model = Sequential()
model.add(Lambda(lambda x: (x /255.0) - 0.5, input_shape=(160,320,3)))
model.add(Convolution2D(6,5,5, activation='relu'))
model.add(MaxPooling2D())
model.add(Convolution2D(6,5,5, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(120))
model.add(Dense(84))
model.add(Dense(1))

model.compile(loss='mse', optimizer = 'adam')
model.fit(X_train,Y_train,validation_split=0.2, shuffle = True, nb_epoch=11)

model.save('model.h5_5')
